# %%
# %sql

GRANT ALL PRIVILEGES ON CATALOG catalog_project TO `eve.sanchez@gmail.com`;

GRANT CREATE, USE SCHEMA ON SCHEMA  catalog_project.bronze to `eve.sanchez@gmail.com`;
GRANT CREATE, USE SCHEMA ON SCHEMA  catalog_project.silver to `eve.sanchez@gmail.com`;
GRANT CREATE, USE SCHEMA ON SCHEMA  catalog_project.golden to `eve.sanchez@gmail.com`;

# %%
# %sql

GRANT SELECT ON TABLE catalog_project.bronze.accounts TO `eve.sanchez@gmail.com`;
GRANT SELECT ON TABLE catalog_project.bronze.client TO `eve.sanchez@gmail.com`;
GRANT SELECT ON TABLE catalog_project.bronze.fileppe TO `eve.sanchez@gmail.com`;
GRANT SELECT ON TABLE catalog_project.bronze.product TO `eve.sanchez@gmail.com`;

GRANT SELECT ON TABLE catalog_project.golden.accountsbyclient TO `eve.sanchez@gmail.com`;
GRANT SELECT ON TABLE catalog_project.golden.totalbyproduct TO `eve.sanchez@gmail.com`;

GRANT SELECT ON TABLE catalog_project.silver.cuentasbyclient TO `eve.sanchez@gmail.com`;
GRANT SELECT ON TABLE catalog_project.silver.totalbyproduct TO `eve.sanchez@gmail.com`

# %%
# %sql

GRANT ALL PRIVILEGES ON CATALOG catalog_project TO `raquel81@gmail.com`;

GRANT CREATE, USE SCHEMA ON SCHEMA  catalog_project.golden to `raquel81@gmail.com`;

GRANT SELECT ON TABLE catalog_project.golden.accountsbyclient TO `raquel81@gmail.com`;
GRANT SELECT ON TABLE catalog_project.golden.totalbyproduct TO `raquel81@gmail.com`;
