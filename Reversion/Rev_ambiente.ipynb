# %%
# %python
dbutils.widgets.removeAll()

# %%
# %sql
CREATE WIDGET TEXT storage_account default="adlssmartdata1921"

# %%
storage_account = dbutils.widgets.get("storage_account")

# %%
# %sql
DROP EXTERNAL LOCATION IF EXISTS `exlt-metastore` FORCE;

# %%
# %sql
DROP EXTERNAL LOCATION IF EXISTS `extl-raw` FORCE;

# %%
# %sql
DROP EXTERNAL LOCATION IF EXISTS `extl-bronze` FORCE;

# %%
# %sql
DROP EXTERNAL LOCATION IF EXISTS `extl-silver` FORCE;

# %%
# %sql
DROP EXTERNAL LOCATION IF EXISTS `extl-golden` FORCE;

# %%
# %sql
DROP CATALOG IF EXISTS catalog_project CASCADE;

# %%
# %sql
DROP SCHEMA IF EXISTS catalog_project.raw;
DROP SCHEMA IF EXISTS catalog_project.bronze;
DROP SCHEMA IF EXISTS catalog_project.silver;
DROP SCHEMA IF EXISTS catalog_project.golden;

# %% [markdown]
# **Eliminar tablas bronze**

# %%
# %sql
DROP TABLE IF EXISTS catalog_project.bronze.fileppe;

# %%
# %sql
DROP TABLE IF EXISTS catalog_project.bronze.product;

# %%
# %sql
DROP TABLE IF EXISTS catalog_project.bronze.client;

# %%
# %sql
DROP TABLE IF EXISTS catalog_project.bronze.accounts;

# %% [markdown]
# **Eliminar tablas silver**

# %%
# %sql
DROP TABLE IF EXISTS catalog_project.silver.productbyclient;

# %%
# %sql
DROP TABLE IF EXISTS catalog_project.silver.accountsfile;

# %%
# %sql
DROP TABLE IF EXISTS catalog_project.silver.totalbyproduct;

# %%
# %sql
DROP TABLE IF EXISTS catalog_project.silver.cuentasbyclient;

# %% [markdown]
# **Eliminar tablas golden**

# %%
# %sql
DROP TABLE IF EXISTS catalog_project.golden.accountsbyclient;

# %%
# %sql
DROP TABLE IF EXISTS catalog_project.golden.totalbyproduct;

# %%
# %python
#dbutils.fs.rm(f"abfss://bronze@{storage_account}.dfs.core.windows.net/",True)
#dbutils.fs.rm(f"abfss://silver@{storage_account}.dfs.core.windows.net/",True)
#dbutils.fs.rm(f"abfss://golden@{storage_account}.dfs.core.windows.net/",True)
